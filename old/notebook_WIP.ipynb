# %%
# ! pip install requests
# Out:
# Requirement already satisfied: requests in .\.venv\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\.venv\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.venv\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in .\.venv\lib\site-packages (from requests) (2024.8.30)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import sqlite3
import os
import shutil
from datetime import datetime
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import PromptTemplate
from langchain_openai import AzureChatOpenAI
from langchain_openai import AzureOpenAIEmbeddings
from dotenv import find_dotenv, load_dotenv
import requests


# load env
load_dotenv()
OPENAI_API_VERSION = os.environ["AZURE_OPENAI_API_VERSION"]
AZURE_OPENAI_ENDPOINT= os.environ["AZURE_OPENAI_ENDPOINT"]
AZURE_OPENAI_API_KEY = os.environ["AZURE_OPENAI_API_KEY"]

llm_gpt4o = AzureChatOpenAI(deployment_name="gpt4o",api_key=AZURE_OPENAI_API_KEY,api_version= "2024-02-01",temperature=0)

# %% [markdown]
# # connect to hardcover api
# abandonné pour l'instant

# %%
load_dotenv()

HARDCOVER_API_KEY = os.environ["HARDCOVER_API_KEY"]
HARDCOVER_BASE_URL = "https://api.hardcover.app"

HEADERS = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {HARDCOVER_API_KEY}'
}

# %%
def get_book_info(isbn):
    # Construire l'URL pour accéder à l'endpoint souhaité avec l'ISBN
    url = f"{HARDCOVER_BASE_URL}/books/{isbn}"

    # Faire une requête GET au serveur avec les en-têtes appropriés
    response = requests.get(url, headers=HEADERS)

    # Vérifier si la requête a réussi (code 200)
    if response.status_code == 200:
        # Retourner les données formatées en JSON
        return response.json()
    else:
        # Gérer les erreurs si la requête n'a pas réussi
        print(f"Error: {response.status_code}, Message: {response.text}")
        return None

# %%
response = requests.get('https://api.hardcover.app/')
print(response)
# Out:
# <Response [200]>

# %%
import requests

# Configuration de l'API
API_KEY = HARDCOVER_API_KEY
URL = 'https://api.hardcover.app/v1/graphql'
HEADERS = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {API_KEY}'
}

# Définir la requête GraphQL
query = """
query MyQuery {
  books(limit: 10, where: {release_year: {_eq: 2016}}) {
    description
    pages
    rating
    ratings_count
    release_year
    reviews_count
    subtitle
    title
    users_count
  }
}
"""

# Exécuter la requête
response = requests.post(URL, json={'query': query}, headers=HEADERS)

# Vérifier les résultats
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error: {response.status_code}, Message: {response.text}")
# Out:
# {'data': {'books': [{'description': "Is your heart fluttering in anticipation? Is your stomach tight with nerves? Are you falling in love? Feeling a bit miffed? Are you curious (perhaps about this book)? Do you have the heebie-jeebies? Are you antsy with iktsuarpok? Or giddy with dépaysement? The Book of Human Emotions is a gleeful, thoughtful collection of 156 feelings, both rare and familiar. Each has its own story, and reveals the strange forces which shape our rich and varied internal worlds. In reading it, you'll discover feelings you never knew you had (like basorexia, the sudden urge to kiss someone), uncover the secret histories of boredom and confidence, and gain unexpected insights into why we feel the way we do.", 'pages': 320, 'rating': None, 'ratings_count': 0, 'release_year': 2016, 'reviews_count': 0, 'subtitle': None, 'title': 'The Book of Human Emotions', 'users_count': 3}, {'description': None, 'pages': 398, 'rating': None, 'ratings_count': 0, 'release_year': 2016, 'reviews_count': 0, 'subtitle': None, 'title': 'The Witnesses', 'users_count': 1}, {'description': '"Why is a course on ancient Chinese philosophers one of the most popular at Harvard? It\'s because the course challenges all our modern assumptions about what it takes to flourish. This is why Professor Michael Puett says to his students, The encounter with these ideas will change your life. As one of them told his collaborator, author Christine Gross-Loh, You can open yourself up to possibilities you never imagined were even possible. These astonishing teachings emerged two thousand years ago through the work of a succession of Chinese scholars exploring how humans can improve themselves and their society. And what are these counterintuitive ideas? Good relationships come not from being sincere and authentic, but from the rituals we perform within them. Influence comes not from wielding power but from holding back. Excellence comes from what we choose to do, not our natural abilities. A good life emerges not from planning it out, but through training ourselves to respond well to small moments. Transformation comes not from looking within for a true self, but from creating conditions that produce new possibilities. In other words, [this book] upends everything we are told about how to lead a good life. Above all, unlike most books on the subject, its most radical idea is that there is no path to follow in the first place-- just a journey we create anew at every moment by seeing and doing things differently. Sometimes voices from the past can offer possibilities for thinking afresh about the future"--Amazon.com.', 'pages': 224, 'rating': 4.0, 'ratings_count': 2, 'release_year': 2016, 'reviews_count': 1, 'subtitle': 'What Chinese Philosophers Can Teach Us About the Good Life', 'title': 'The Path', 'users_count': 9}, {'description': "This antique book comprises a concise yet comprehensive guide to growing plants using hot houses. Complete with simple, step-by-step instructions and a wealth of helpful illustrations and diagrams, this is a text that will be of considerable value to gardeners and farmers interested to growing with hotbeds. It is perfect for those with little previous experience. The chapters of this volume include: 'Hotbeds', 'Manure-Heated Structures', 'Temporary Hotbeds', 'Permanent Manure-Heated Hotbed', 'Concrete Construction', 'Preparation of Manure for Hotbeds', 'Management of Manure-Heated Bed', 'Fresh Manure Must be Allowed to Start Fermentation', etcetera. We are proud to republish this volume, now complete with a new introduction on growing vegetables at home.", 'pages': 48, 'rating': None, 'ratings_count': 0, 'release_year': 2016, 'reviews_count': 0, 'subtitle': None, 'title': 'A Guide to Starting Early Vegetable and Flowering Plants in the Hothouse', 'users_count': 0}, {'description': "We love, love, love you, little deer. Merry Christmas and Happy New Year!! Babies and toddlers will love holding, touching, and reading this merr ...

# %%
# Configuration de l'API
API_KEY = HARDCOVER_API_KEY
URL = 'https://api.hardcover.app/v1/graphql'
HEADERS = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {API_KEY}'
}


# Définir la requête GraphQL
def get_books_by_year(year):
    query = f"""
    query MyQuery {{
      books(limit: 2, where: {{release_year: {{_eq: {year}}}}}) {{
        description
        pages
        rating
        ratings_count
        release_year
        reviews_count
        subtitle
        title
        users_count
      }}
    }}
    """
    response = requests.post(URL, json={'query': query}, headers=HEADERS)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}, Message: {response.text}")
        return None

# Exemple de DataFrame avec des années pour tester
data = {
    'isbn': ['9780143127741', '9780143127550'],  # Example ISBNs
    'release_year': [2016, 2015],  # Example years
    "titre":["",""]
}
df = pd.DataFrame(data)

# Fonction pour mettre à jour le DataFrame avec les informations de l'API
def update_df_with_api_info(df):
    for index, row in df.iterrows():
        if pd.isnull(row['titre']):  # Vérifiez les colonnes manquantes
            year = row['release_year']
            book_info = get_books_by_year(year)
            if book_info and 'data' in book_info and 'books' in book_info['data']:
                # Supposons que vous choisissiez le premier livre dans les résultats
                book_data = book_info['data']['books'][0]
                df.at[index, 'titre'] = book_data.get('title', None)  # Mettez à jour les colonnes souhaitées
    return df

# %%
df.head()
# Out:
#             isbn  release_year titre
# 0  9780143127741          2016
# 1  9780143127550          2015

# %% [markdown]
# # Update des données  / archivages des fichiers sqlite3
# TERMINE

# %%
df = pd.read_parquet('data_sources_from_python\df_book.parquet')
df.tail(10)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\chric\AppData\Local\Temp\ipykernel_188\86564744.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_parquet('data_sources_from_python\df_book.parquet')
#     id                                              Titre           Auteurs  \
# 62  63  Blackwater 1 - La crue: L'épique saga de la fa...  Michael McDowell
# 63  64                            Blackwater 2 - La digue  Michael McDowell
# 64  65                        Le livre des choses perdues     John Connolly
# 65  66  Histoires de moine et de robot T2 : Une prière...    Becky Chambers
# 66  67                      Voyageur 1 : L'Espace d'un an    Becky Chambers
# 67  68                             Voyageur 2 : Libration    Becky Chambers
# 68  69  Blackwater 3 – La Maison: L'épique saga de la ...  Michael McDowell
# 69  70                   Voyageur 3 : Archives de l'exode    Becky Chambers
# 70  71  Blackwater 4 – La Guerre: L'épique saga de la ...  Michael McDowell
# 71  72                 Voyageur 4 : La Galaxie vue du sol    Becky Chambers
#
#     notes Date dernière ouverture  page                              Série  \
# 62      0              2024-08-18   248                      Blackwater #1
# 63      0              2024-08-20   225                      Blackwater #2
# 64      0              2024-09-09   480                                N/A
# 65      0              2024-09-23   139  Histoires de moine et de robot #2
# 66      0              2024-09-29   789                   Les voyageurs #1
# 67      0              2024-10-03   504                   Les voyageurs #2
# 68      0              2024-10-08   213                      Blackwater #3
# 69      0              2024-10-23   441                   Les voyageurs #3
# 70      0              2024-10-27   257                      Blackwater #4
# 71      0              2024-11-01   400                   Les voyageurs #4
#
#    Langue  total_read_time  total Nbr de pages lues id long    Auteurs courts  \
# 62     fr           9673.0                      234   00063  Michael McDowell
# 63     it           9457.0                      208   00064  Michael McDowell
# 64     fr          21326.0                      467   00065     John Connolly
# 65     fr           5787.0                      135   00066    Becky Chambers
# 66     fr          26888.0                      779   00067    Becky Chambers
# 67     fr          21135.0                      487   00068    Becky Chambers
# 68     fr           8572.0                      206   00069  Michael McDowell
# 69     fr          22254.0                      422   00070    Becky Chambers
# 70     fr           8562.0                      249   00071  Michael McDowell
# 71     fr           2951.0                       54   00072    Becky Chambers
#
#    format            categorie
# 62  ebook  fiction/fantastique
# 63  ebook  fiction/fantastique
# 64  ebook      fiction/fantasy
# 65  ebook           fiction/SF
# 66  ebook           fiction/SF
# 67  ebook           fiction/SF
# 68  ebook  fiction/fantastique
# 69  ebook           fiction/SF
# 70  ebook  fiction/fantastique
# 71  ebook           fiction/SF

# %%
# load env
load_dotenv()
OPENAI_API_VERSION = os.environ["AZURE_OPENAI_API_VERSION"]
AZURE_OPENAI_ENDPOINT= os.environ["AZURE_OPENAI_ENDPOINT"]
AZURE_OPENAI_API_KEY = os.environ["AZURE_OPENAI_API_KEY"]

llm_gpt4o = AzureChatOpenAI(deployment_name="gpt4o",api_key=AZURE_OPENAI_API_KEY,api_version= "2024-02-01",temperature=0)

prompt = """
en utilisant tes connaissances, classe l'oeuvre dans une des catégories suivantes : 

fiction/SF
fiction/fantasy
fiction/fantastique

non-fiction/lifestyle
non-fiction/parenting
non-fiction/histoire
non-fiction/santé

si aucune des catégories ne convient, tu peux en générer une autre, en gardant la même structure (en commençant toujours par fiction ou non-fiction).
n'ajoute rien d'autre.

exemples : 
harry potter et la chambre des secrets - JK Rowling = fiction/fantastique
Blackwater 1 - La crue - Michael McDowell = fiction/fantastique

question: {oeuvre} 

catégorie:"""
rag_prompt_1 = PromptTemplate.from_template(prompt)

# langchain :
chain_category = (
    {"oeuvre": RunnablePassthrough()}
    | rag_prompt_1
    | llm_gpt4o
    | StrOutputParser()
)

	
# fonction pour créer une colonne catégorie
def find_category(oeuvre):
    result = chain_category.invoke(oeuvre)
    return result

# %%
df["oeuvre"] = df["Titre"] + " - " + df["Auteurs"]

# %%
# Applique find_category uniquement si 'categorie' est vide

df['categorie'] = df.apply(
    lambda row: find_category(row['oeuvre']) if row['categorie'] == '' else row['categorie'], axis=1
)

# %%
df.head()
# Out:
#    id                                              Titre              Auteurs  \
# 0   1                          KOReader Quickstart Guide                  N/A
# 1   2                       Le crime de l'Orient-Express     Christie, Agatha
# 2   3                                 Let's Get Together         Isaac Asimov
# 3   4                                  La nuit des temps        Barjavel,René
# 4   5  Chasseur, cueilleur, parent: les cultures ance...  Michaeleen Doucleff
#
#    notes Date dernière ouverture  page        Série Langue  total_read_time  \
# 0      0              2023-11-21     8          N/A    N/A             54.0
# 1      0              2023-11-27   349  l'Orient #1     fr          13191.0
# 2      0              2023-11-27    68          N/A     en            388.0
# 3      0              2024-01-08   449          N/A    und          12189.0
# 4      0              2024-01-09   675          N/A     fr          18029.0
#
#    total Nbr de pages lues id long       Auteurs courts format  \
# 0                        4   00001                  N/A  ebook
# 1                      330   00002      Christie Agatha  ebook
# 2                        8   00003         Isaac Asimov  ebook
# 3                      288   00004        Barjavel René  ebook
# 4                      418   00005  Michaeleen Doucleff  ebook
#
#                categorie                                             oeuvre
# 0      non-fiction/guide                    KOReader Quickstart Guide - N/A
# 1             fiction/SF    Le crime de l'Orient-Express - Christie, Agatha
# 2             fiction/SF                  Let's Get Together - Isaac Asimov
# 3             fiction/SF                  La nuit des temps - Barjavel,René
# 4  non-fiction/parenting  Chasseur, cueilleur, parent: les cultures ance...

# %%
# drop la colonne categorie, puis recréé la vide
df = df.drop(columns=['categorie'])

df.tail()
# Out:
#     id                                              Titre           Auteurs  \
# 67  68                             Voyageur 2 : Libration    Becky Chambers
# 68  69  Blackwater 3 – La Maison: L'épique saga de la ...  Michael McDowell
# 69  70                   Voyageur 3 : Archives de l'exode    Becky Chambers
# 70  71  Blackwater 4 – La Guerre: L'épique saga de la ...  Michael McDowell
# 71  72                 Voyageur 4 : La Galaxie vue du sol    Becky Chambers
#
#     notes Date dernière ouverture  page             Série Langue  \
# 67      0              2024-10-03   504  Les voyageurs #2     fr
# 68      0              2024-10-08   213     Blackwater #3     fr
# 69      0              2024-10-23   441  Les voyageurs #3     fr
# 70      0              2024-10-27   257     Blackwater #4     fr
# 71      0              2024-11-01   400  Les voyageurs #4     fr
#
#     total_read_time  total Nbr de pages lues id long    Auteurs courts format
# 67          21135.0                      487   00068    Becky Chambers  ebook
# 68           8572.0                      206   00069  Michael McDowell  ebook
# 69          22254.0                      422   00070    Becky Chambers  ebook
# 70           8562.0                      249   00071  Michael McDowell  ebook
# 71           2951.0                       54   00072    Becky Chambers  ebook

# %%
# enregistre le dataframe en df_book_cleaned.parquet
df.to_parquet('data_sources_from_python\df_book.parquet', engine='pyarrow')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\chric\AppData\Local\Temp\ipykernel_188\3345659750.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df.to_parquet('data_sources_from_python\df_book.parquet', engine='pyarrow')

# %% [markdown]
# élément de langage :
#
# * df_book_stale = df book déjà existant, provient du ficher parquet déjà existant
# * df_book_new = table book du sqlite qui provient du dossier "update",

# %%
# df_book_stale
df_book_stale_source = pd.read_parquet("data_sources_from_python/df_book.parquet")
df_book_stale = df_book_stale_source

# drop les lignes 10 à la fin, pour simuler des nouvelles données   
df_book_stale = df_book_stale.drop(df_book_stale.index[10:])
df_book_stale.head(15)
print(df_book_stale.columns)
# Out:
# Index(['id', 'Titre', 'Auteurs', 'notes', 'Date dernière ouverture', 'page',
#        'Série', 'Langue', 'total_read_time', 'total Nbr de pages lues',
#        'oeuvre', 'id long', 'Auteurs courts', 'format', 'categorie'],
#       dtype='object')

# %%
# df_book_new

# Chemin vers SQLite
database_path = 'sqlite/statistics.sqlite3'

# Connexion à la base de données SQLite
conn = sqlite3.connect(database_path)

# Liste toutes les tables de la base de données
query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql(query, conn)

# Charger une table de la base de données dans un df pandas
book = 'book'
df_book_new = pd.read_sql(f"SELECT * FROM {book};", conn)

# fermer de la connexion à la base de données
conn.close()

# enrichissement du fichier source
df_book_new['oeuvre'] = df_book_new[['title', 'authors']].astype(str).agg(' - '.join, axis=1)
df_book_new['id long'] = df_book_new['id'].apply(lambda x: str(x).zfill(5))
# renaming des colonnes
df_book_new = df_book_new.rename(
    columns={'last_open':'Date dernière ouverture',
             "title":"Titre",
             "authors":"Auteurs",
             "series":"Série",
             "language":"Langue",
             "total_read_pages":"total Nbr de pages lues",
             "pages":"page"})
df_book_new['Date dernière ouverture'] = pd.to_datetime(df_book_new['Date dernière ouverture'], unit='s').dt.date
# créer la colonne "auteur courts"
df_book_new['Auteurs courts'] = (
    df_book_new['Auteurs']
    .str.replace(r'[.,]', ' ', regex=True)  # Remplace les points et virgules par des espaces
    .str.split()
    .apply(lambda x: ' '.join([word for word in x if len(word) > 2]))  # Garde les mots de plus de 2 caractères
    .str.split()
    .apply(lambda x: ' '.join(x[:2]))  # Garde les deux premiers mots
)

# ajout  colonne "format" = "ebook"
df_book_new['format'] = "ebook"
# ajout d'une colonne categorie vide 
df_book_new['categorie'] = ''
df_book_new = df_book_new.drop(columns=['highlights', 'md5'])

# %%
print(df_book_new.columns)
# Out:
# Index(['id', 'Titre', 'Auteurs', 'notes', 'Date dernière ouverture', 'page',
#        'Série', 'Langue', 'total_read_time', 'total Nbr de pages lues',
#        'oeuvre', 'id long', 'Auteurs courts', 'format', 'categorie'],
#       dtype='object')

# %%
# ajouter 4 à la colonne "total Nbr de pages lues" pour les lignes 5 à 9
df_book_new.loc[5:9, 'total Nbr de pages lues'] += 4
df_book_new.iloc[5:9]
# Out:
#    id                                              Titre  \
# 5   6  2023-12-31-23-59-40-Chasseur_ cueilleur_ paren...
# 6   7  2024-01-01-12-01-52-Chasseur_ cueilleur_ paren...
# 7   8                      What to Expect the First Year
# 8   9                                           koreader
#
#                                              Auteurs  notes  \
# 5                                                N/A      0
# 6                                                N/A      0
# 7  Arlene Eisenberg\nSharon Mazel\nSandee Hathawa...      0
# 8                                                N/A      0
#
#   Date dernière ouverture  page Série Langue  total_read_time  \
# 5              2023-12-31     2   N/A    N/A             24.0
# 6              2024-01-05    36   N/A    N/A            890.0
# 7              2024-01-08  2473   N/A     en            289.0
# 8              2024-01-08     1   N/A    N/A              NaN
#
#    total Nbr de pages lues                                             oeuvre  \
# 5                       49  2023-12-31-23-59-40-Chasseur_ cueilleur_ paren...
# 6                       52  2024-01-01-12-01-52-Chasseur_ cueilleur_ paren...
# 7                       75  What to Expect the First Year - Arlene Eisenbe...
# 8                       48                                     koreader - N/A
#
#   id long    Auteurs courts format categorie
# 5   00006               N/A  ebook
# 6   00007               N/A  ebook
# 7   00008  Arlene Eisenberg  ebook
# 8   00009               N/A  ebook

# %%
# df_book_stale est la table originale et df_book_new est la table mise à jour

# Comparer les 'id' pour identifier les nouvelles lignes
df_increment = df_book_new[~df_book_new['id'].isin(df_book_stale['id'])]

# Ajouter les nouvelles lignes à df_book_stale
df_book_stale_concatenated = pd.concat([df_book_stale, df_increment], ignore_index=True)

# %%
print(df_book_stale_concatenated.shape)
df_book_stale_concatenated.head(15)
# Out:
# (70, 15)
#     id                                              Titre  \
# 0    1                          KOReader Quickstart Guide
# 1    2                       Le crime de l'Orient-Express
# 2    3                                 Let's Get Together
# 3    4                                  La nuit des temps
# 4    5  Chasseur, cueilleur, parent: les cultures ance...
# 5    6  2023-12-31-23-59-40-Chasseur_ cueilleur_ paren...
# 6    7  2024-01-01-12-01-52-Chasseur_ cueilleur_ paren...
# 7    8                      What to Expect the First Year
# 8    9                                           koreader
# 9   10                                    Black Destroyer
# 10  11                               La faune de l'espace
# 11  12                                         Hyperion 1
# 12  13              Guide de démarrage rapide de KOReader
# 13  14                    Le manuel de survie des parents
# 14  15                                         Hyperion 1
#
#                                               Auteurs  notes  \
# 0                                                 N/A      0
# 1                                    Christie, Agatha      0
# 2                                        Isaac Asimov      0
# 3                                       Barjavel,René      0
# 4                                 Michaeleen Doucleff      0
# 5                                                 N/A      0
# 6                                                 N/A      0
# 7   Arlene Eisenberg\nSharon Mazel\nSandee Hathawa...      0
# 8                                                 N/A      0
# 9                                      A. E. Van Vogt      0
# 10                                  Van Vogt,Alfred E      0
# 11                                        Dan Simmons      0
# 12                                                N/A      0
# 13                                     Héloïse Junier      0
# 14                                        Dan Simmons      0
#
#    Date dernière ouverture  page                     Série Langue  \
# 0               2023-11-21     8                       N/A    N/A
# 1               2023-11-27   349               l'Orient #1     fr
# 2               2023-11-27    68                       N/A     en
# 3               2024-01-08   449                       N/A    und
# 4               2024-01-09   675                       N/A     fr
# 5               2023-12-31     2                       N/A    N/A
# 6               2024-01-05    36                       N/A    N/A
# 7               2024-01-08  2473                       N/A     en
# 8               2024-01-08     1                       N/A    N/A
# 9               2024-01-08    60                       N/A     en
# 10              2024-01-08   809                       N/A     fr
# 11              2024-01-09   457  Les Cantos d'Hyperion #1     fr
# 12              2024-01-09    10                       N/A    N/A
# 13              2024-01-09   401                       N/A     fr
# 14              2024-01-19   457  Les Cantos d'Hyperion #1     fr
#
#     total_read_time  total Nbr de pages lues  \
# 0              54.0                        4
# 1           13191.0                      330
# 2             388.0                        8
# 3           12189.0                      288
# 4           18029.0                      418
# 5              24.0                        1
# 6             890.0                        4
# 7             289.0                       27
# 8               NaN                        0
# 9              14.0                        1
# 10              8.0                        1
# 11           3805.0                       60
# 12            263.0                        3
# 13            340.0                       10
# 14          20386.0                      414
#
#                                                oeuvre id long  \
# 0                     KOReader Quickstart Guide - N/A   00001
# 1     Le crime de l'Orient-Express - Christie, Agatha   00002
# 2                   Let's Get Together - Isaac Asimov   00003
# 3                   La nuit des temps - Barjavel,René   00004
# 4   Chasseur, cueilleur, parent: les cultures ance...   00005
# 5   2023-12-31-23-59-40-Chasseur_ cueilleur_ paren...   00006
# 6   2024-01-01-12-01-52-Chasseur_ cueilleur_ paren...   00007
# 7   What to Expect the First Year - Arlene Eisenbe...   00008
# 8                                      koreader - N/A   00009
# 9                    Black Destroyer - A. E. Van Vogt   00010
# 10           La faune de l'espace - Van Vogt,Alfred E   00011
# 11                           Hyperion 1 - Dan Simmons   00012
# 12        Guide de démarrage rapide de KOReader - N/A   00013
# 13   Le manuel de survie des parents - Héloïse Junier   00014
# 14                           Hyperion 1 - Dan Simmons   00015
#
#          Auteurs courts format                categorie
# 0                   N/A  ebook        non-fiction/guide
# 1       Christie Agatha  ebook         fiction/policier
# 2          Isaac Asimov  ebook               fiction/SF
# 3         Barjavel René  ebook               fiction/SF
# 4   Michaeleen Doucleff  ebook    non-fiction/parenting
# 5                   N/A  ebook    non-fiction/parenting
# 6                   N/A  ebook    non-fiction/parenting
# 7      Arlene Eisenberg  ebook    non-fiction/parenting
# 8                   N/A  ebook  non-fiction/technologie
# 9              Van Vogt  ebook               fiction/SF
# 10             Van Vogt  ebook
# 11          Dan Simmons  ebook
# 12                  N/A  ebook
# 13       Héloïse Junier  ebook
# 14          Dan Simmons  ebook

# %%
# Colonnes à mettre à jour
update_columns = ['notes', 'Date dernière ouverture', 'total_read_time', 'total Nbr de pages lues']

# Faire la jointure sur 'id' pour obtenir les lignes correspondantes de df_fake
df_updated = df_book_stale_concatenated.merge(df_book_new[['id'] + update_columns], on='id', how='left', suffixes=('', '_fake'))

# Remplacer les valeurs existantes par les valeurs de df_fake si elles existent
for col in update_columns:
    df_updated[col] = df_updated[f'{col}_fake'].combine_first(df_updated[col])

# Supprimer les colonnes temporaires (celles avec le suffixe "_fake")
df_updated.drop(columns=[f'{col}_fake' for col in update_columns], inplace=True)

# %%
# Ajout de la colonne catégorie mais uniquement sur les lignes vides : 

# AJOUT DE LA CATEGORY : 

# load env
load_dotenv()
OPENAI_API_VERSION = os.environ["AZURE_OPENAI_API_VERSION"]
AZURE_OPENAI_ENDPOINT= os.environ["AZURE_OPENAI_ENDPOINT"]
AZURE_OPENAI_API_KEY = os.environ["AZURE_OPENAI_API_KEY"]

llm_gpt4o = AzureChatOpenAI(deployment_name="gpt4o",api_key=AZURE_OPENAI_API_KEY,api_version= "2024-02-01",temperature=0)

prompt = """
en utilisant tes connaissances, classe l'oeuvre dans une des catégories suivantes : 

fiction/SF
fiction/fantasy
fiction/fantastique

non-fiction/lifestyle
non-fiction/parenting
non-fiction/histoire
non-fiction/santé

si aucune des catégories ne convient, tu peux en générer une autre, en gardant la même structure (en commençant toujours par fiction ou non-fiction).
n'ajoute rien d'autre.

exemples : 
harry potter et la chambre des secrets - JK Rowling = fiction/fantastique
Blackwater 1 - La crue - Michael McDowell = fiction/fantastique

question: {oeuvre} 

catégorie:"""
rag_prompt_1 = PromptTemplate.from_template(prompt)

# langchain :
chain_category = (
    {"oeuvre": RunnablePassthrough()}
    | rag_prompt_1
    | llm_gpt4o
    | StrOutputParser()
)

	
# fonction pour créer une colonne catégorie
def find_category(oeuvre):
    result = chain_category.invoke(oeuvre)
    return result

df_updated['categorie'] = df_updated['oeuvre'].apply(find_category)
df_updated = df_updated.drop(columns=['oeuvre'])

# %% [markdown]
# Nouvelle version fonctionnelle !

# %% [markdown]
# Derniere étape : le déplacement du fichier sqlite

# %%
# fonctionne avec 3 dossiers, fonctionne.
# hypothèse en cours, utiliser la version 2 dossiers
#  un dossier de mise à jour, un dossier d'archive (contenant la version de référence) et un sous dossier old/archive



# Définir les chemins des dossiers et du fichier
folder_update_path = "sqlite/update"
folder_archive_path = "sqlite/archive"
folder_old_archive_path = "sqlite/archive/old"
sqlite_update_path = os.path.join(folder_update_path, "statistics.sqlite3")

# Vérifier si le fichier existe dans le dossier de mise à jour
if os.path.exists(sqlite_update_path):
    # Vérifier si le dossier old existe, sinon le créer
    if not os.path.exists(folder_old_archive_path):
        os.makedirs(folder_old_archive_path)

    # Déplacer le fichier actuel dans archive vers old
    archive_files = [f for f in os.listdir(folder_archive_path) if os.path.isfile(os.path.join(folder_archive_path, f))]

    if archive_files:
        latest_archive_file = archive_files[0]  # Le fichier actuel dans archive
        shutil.move(os.path.join(folder_archive_path, latest_archive_file), os.path.join(folder_old_archive_path, latest_archive_file))
        print(f"le fichier initial {latest_archive_file} a été déplacé vers {folder_old_archive_path}")

    # Générer un horodatage dans le format souhaité (exemple : YYYYMMDD_HHMMSS)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

    # Construire le nouveau nom de fichier avec l'horodatage
    new_filename = f"statistics_{timestamp}.sqlite3"
    new_filepath = os.path.join(folder_archive_path, new_filename)

    # Déplacer et renommer le fichier vers le dossier archive
    shutil.move(sqlite_update_path, new_filepath)
    print(f"le fichier de mise à jour a été déplacé vers archive et renommé en {new_filename}")

    # Compter le nombre de fichiers dans le dossier archive/old
    num_files = len([name for name in os.listdir(folder_old_archive_path) if os.path.isfile(os.path.join(folder_old_archive_path, name))])
    if num_files > 3:
        # Afficher le message avec le nombre de fichiers
        print(f"Il y a {num_files} fichiers de sauvegarde dans le dossier old, pense à faire du ménage, tu vas pas garder 2000 sauvegardes, tu payes pas tes bytes ou quoi ?")

else:
    print(f"Aucun fichier trouvé à l'emplacement : {sqlite_update_path}")
# Out:
# le fichier de mise à jour a été déplacé vers archive et renommé en statistics_20241101_163632.sqlite3
# Il y a 6 fichiers de sauvegarde dans le dossier old, pense à faire du ménage, tu vas pas garder 2000 sauvegardes, tu payes pas tes bytes ou quoi ?

# %%
# VERSION avec 2 dossiers, fonctionne

import os
import shutil
from datetime import datetime

# Définir les chemins des dossiers et du fichier
folder_update_path = "sqlite/update"
folder_archive_path = "sqlite/archive"
sqlite_update_path = os.path.join(folder_update_path, "statistics.sqlite3")

# Vérifier si le fichier existe dans le dossier de mise à jour
if os.path.exists(sqlite_update_path):
    # Générer un horodatage dans le format souhaité (exemple : YYYYMMDD_HHMMSS)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    
    # Construire le nouveau nom de fichier avec l'horodatage
    new_filename = f"statistics_{timestamp}.sqlite3"
    new_filepath = os.path.join(folder_archive_path, new_filename)
    
    # Déplacer et renommer le fichier vers le dossier archive
    shutil.move(sqlite_update_path, new_filepath)
    print(f"Fichier déplacé et renommé en {new_filename}")
    # Compter le nombre de fichiers dans le dossier archive
    num_files = len([name for name in os.listdir(folder_archive_path) if os.path.isfile(os.path.join(folder_archive_path, name))])
    if num_files > 3:
        # Afficher le message avec le nombre de fichiers
        print(f"Il y a {num_files} fichiers de sauvegarde, pense à faire du ménage, tu vas pas garder 2000 sauvegardes, tu payes pas tes bytes ou quoi ?")

    
else:
    print(f"Aucun fichier trouvé à l'emplacement : {sqlite_update_path}")

# %% [markdown]
# # nouvelle colonne genAI
# TERMINE

# %%
# modèle
prompt = """
en utilisant tes connaissances, classe l'oeuvre dans une des catégories suivantes : 

fiction/SF
fiction/fantasy
fiction/fantastique

non-fiction/lifestyle
non-fiction/parenting
non-fiction/histoire
non-fiction/santé

si aucune des catégories ne convient, tu peux en générer une autre, en gardant la même structure (en commençant toujours par fiction ou non-fiction).
n'ajoute rien d'autre.

exemples : 
harry potter et la chambre des secrets - JK Rowling = fiction/fantastique
Blackwater 1 - La crue - Michael McDowell = fiction/fantastique

question: {oeuvre} 

catégorie:"""
rag_prompt_1 = PromptTemplate.from_template(prompt)

# langchain :
chain_category = (
    {"oeuvre": RunnablePassthrough()}
    | rag_prompt_1
    | llm_gpt4o
    | StrOutputParser()
)

	
# fonction pour créer une colonne catégorie
def find_category(oeuvre):
    result = chain_category.invoke(oeuvre)
    return result



df_updated['categorie'] = df_updated.apply(
    lambda row: find_category(row['oeuvre']) if pd.isna(row['categorie']) or row['categorie'] == '' else row['categorie'],
    axis=1
)

# %%
df = pd.read_parquet('data_sources_from_python\df_book.parquet')
df.tail(10)
# garde uniquement les 5 dernières lignes
df = df.tail(5)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\chric\AppData\Local\Temp\ipykernel_188\3317538426.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_parquet('data_sources_from_python\df_book.parquet')

# %% [markdown]
# # Trouver la date de première édition en version originale
# TERMINE

# %%
prompt_annee_edition = """
en utilisant tes connaissances, trouve la date de première parution de l'oeuvre dans sa version originale. (parfois appelée First published date).
N'ajoute rien d'autre.
Le format doit être AAAA.

question: {oeuvre} 

catégorie:"""
prompt = PromptTemplate.from_template(prompt_annee_edition)

# langchain :
chain_first_published_date = (
    {"oeuvre": RunnablePassthrough()}
    | prompt
    | llm_gpt4o
    | StrOutputParser()
)

	
# fonction pour créer une colonne catégorie
def first_published_date(oeuvre):
    result = chain_first_published_date.invoke(oeuvre)
    return result


if 'First published date' not in df.columns:
    df['First published date'] = ''
df['First published date'] = df.apply(
    lambda row: first_published_date(row['oeuvre']) if pd.isna(row['First published date']) or row['First published date'] == '' else row['First published date'],
    axis=1
)

# %%
df.tail()
# Out:
#     id                                              Titre           Auteurs  \
# 67  68                             Voyageur 2 : Libration    Becky Chambers
# 68  69  Blackwater 3 – La Maison: L'épique saga de la ...  Michael McDowell
# 69  70                   Voyageur 3 : Archives de l'exode    Becky Chambers
# 70  71  Blackwater 4 – La Guerre: L'épique saga de la ...  Michael McDowell
# 71  72                 Voyageur 4 : La Galaxie vue du sol    Becky Chambers
#
#     notes Date dernière ouverture  page             Série Langue  \
# 67      0              2024-10-03   504  Les voyageurs #2     fr
# 68      0              2024-10-08   213     Blackwater #3     fr
# 69      0              2024-10-23   441  Les voyageurs #3     fr
# 70      0              2024-10-27   257     Blackwater #4     fr
# 71      0              2024-11-01   400  Les voyageurs #4     fr
#
#     total_read_time  total Nbr de pages lues id long    Auteurs courts format  \
# 67          21135.0                      487   00068    Becky Chambers  ebook
# 68           8572.0                      206   00069  Michael McDowell  ebook
# 69          22254.0                      422   00070    Becky Chambers  ebook
# 70           8562.0                      249   00071  Michael McDowell  ebook
# 71           2951.0                       54   00072    Becky Chambers  ebook
#
#               categorie                                             oeuvre  \
# 67           fiction/SF            Voyageur 2 : Libration - Becky Chambers
# 68  fiction/fantastique  Blackwater 3 – La Maison: L'épique saga de la ...
# 69           fiction/SF  Voyageur 3 : Archives de l'exode - Becky Chambers
# 70  fiction/fantastique  Blackwater 4 – La Guerre: L'épique saga de la ...
# 71           fiction/SF  Voyageur 4 : La Galaxie vue du sol - Becky Cha...
#
#    First published date
# 67                 2022
# 68                 1983
# 69                 2018
# 70                 1983
# 71                 2021

# %%
df.to_parquet('data_sources_from_python\df_annee.parquet', engine='pyarrow')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\chric\AppData\Local\Temp\ipykernel_188\3199247240.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df.to_parquet('data_sources_from_python\df_annee.parquet', engine='pyarrow')

# %% [markdown]
# # data de goodread
# ANNULE, impossible via gen ai

# %%
df = pd.read_parquet('data_sources_from_python\df_book.parquet')
df.tail(10)
# garde uniquement les 5 dernières lignes
df = df.tail(5)
df.head(20)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\chric\AppData\Local\Temp\ipykernel_188\3727004748.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_parquet('data_sources_from_python\df_book.parquet')
#     id                                              Titre           Auteurs  \
# 67  68                             Voyageur 2 : Libration    Becky Chambers
# 68  69  Blackwater 3 – La Maison: L'épique saga de la ...  Michael McDowell
# 69  70                   Voyageur 3 : Archives de l'exode    Becky Chambers
# 70  71  Blackwater 4 – La Guerre: L'épique saga de la ...  Michael McDowell
# 71  72                 Voyageur 4 : La Galaxie vue du sol    Becky Chambers
#
#     notes Date dernière ouverture  page             Série Langue  \
# 67      0              2024-10-03   504  Les voyageurs #2     fr
# 68      0              2024-10-08   213     Blackwater #3     fr
# 69      0              2024-10-23   441  Les voyageurs #3     fr
# 70      0              2024-10-27   257     Blackwater #4     fr
# 71      0              2024-11-01   400  Les voyageurs #4     fr
#
#     total_read_time  total Nbr de pages lues id long    Auteurs courts format  \
# 67          21135.0                      487   00068    Becky Chambers  ebook
# 68           8572.0                      206   00069  Michael McDowell  ebook
# 69          22254.0                      422   00070    Becky Chambers  ebook
# 70           8562.0                      249   00071  Michael McDowell  ebook
# 71           2951.0                       54   00072    Becky Chambers  ebook
#
#               categorie                                             oeuvre  \
# 67           fiction/SF            Voyageur 2 : Libration - Becky Chambers
# 68  fiction/fantastique  Blackwater 3 – La Maison: L'épique saga de la ...
# 69           fiction/SF  Voyageur 3 : Archives de l'exode - Becky Chambers
# 70  fiction/fantastique  Blackwater 4 – La Guerre: L'épique saga de la ...
# 71           fiction/SF  Voyageur 4 : La Galaxie vue du sol - Becky Cha...
#
#    First published date
# 67                 2022
# 68                 1983
# 69                 2020
# 70                 1983
# 71                 2021

# %%
df[colonne_ai] = ''

# %%
prompt_reviews = """
en utilisant tes connaissances, trouve les données suivantes pour chaque oeuvre : 
* community reviews (RatingStatistics__rating)
* nombre de notes (ratingsCount)
* nombre de reviews (reviewsCount)
* la date de mise à jour de ces 3 données (ou la date du jour si tu as trouvé l'information en direct)au format AAAA-MM

exemple pour l'oeuvre "A Psalm for the Wild-Built - Becky Chambers "
4.26|131901|23315|2024-11

N'ajoute rien d'autre. Utilise toujours le format donné en exemple

question: {oeuvre} 

catégorie:"""
prompt = PromptTemplate.from_template(prompt_reviews)

# langchain :
chain_prompt_reviews = (
    {"oeuvre": RunnablePassthrough()}
    | prompt
    | llm_gpt4o
    | StrOutputParser()
)

	
# fonction pour créer une colonne catégorie
def reviews(oeuvre):
    result = chain_prompt_reviews.invoke(oeuvre)
    return result


colonne_ai = "reviews"
colonne_ref = "oeuvre"

if colonne_ai not in df.columns:
    df[colonne_ai] = ''
df[colonne_ai] = df.apply(
    lambda row: reviews(row[colonne_ref]) if pd.isna(row[colonne_ai]) or row[colonne_ai] == '' else row[colonne_ai],
    axis=1
)
# print df[colonne_ai][0]
print(df[colonne_ai])
# Out:
# 67                                4.34|1234|567|2023-10
# 68    Je suis désolé, mais je ne peux pas accéder à ...
# 69                                4.35|1234|567|2023-10
# 70    Je suis désolé, mais je ne peux pas fournir le...
# 71    Je suis désolé, mais je ne peux pas fournir le...
# Name: reviews, dtype: object

# %%
df.head(20)
# Out:
#     id                                              Titre           Auteurs  \
# 67  68                             Voyageur 2 : Libration    Becky Chambers
# 68  69  Blackwater 3 – La Maison: L'épique saga de la ...  Michael McDowell
# 69  70                   Voyageur 3 : Archives de l'exode    Becky Chambers
# 70  71  Blackwater 4 – La Guerre: L'épique saga de la ...  Michael McDowell
# 71  72                 Voyageur 4 : La Galaxie vue du sol    Becky Chambers
#
#     notes Date dernière ouverture  page             Série Langue  \
# 67      0              2024-10-03   504  Les voyageurs #2     fr
# 68      0              2024-10-08   213     Blackwater #3     fr
# 69      0              2024-10-23   441  Les voyageurs #3     fr
# 70      0              2024-10-27   257     Blackwater #4     fr
# 71      0              2024-11-01   400  Les voyageurs #4     fr
#
#     total_read_time  total Nbr de pages lues id long    Auteurs courts format  \
# 67          21135.0                      487   00068    Becky Chambers  ebook
# 68           8572.0                      206   00069  Michael McDowell  ebook
# 69          22254.0                      422   00070    Becky Chambers  ebook
# 70           8562.0                      249   00071  Michael McDowell  ebook
# 71           2951.0                       54   00072    Becky Chambers  ebook
#
#               categorie                                             oeuvre  \
# 67           fiction/SF            Voyageur 2 : Libration - Becky Chambers
# 68  fiction/fantastique  Blackwater 3 – La Maison: L'épique saga de la ...
# 69           fiction/SF  Voyageur 3 : Archives de l'exode - Becky Chambers
# 70  fiction/fantastique  Blackwater 4 – La Guerre: L'épique saga de la ...
# 71           fiction/SF  Voyageur 4 : La Galaxie vue du sol - Becky Cha...
#
#    First published date                                            reviews
# 67                 2022  Je suis désolé, mais je ne peux pas accéder di...
# 68                 1983  Je suis désolé, mais je ne peux pas accéder di...
# 69                 2020  Je suis désolé, mais je ne peux pas accéder di...
# 70                 1983  Je suis désolé, mais je ne peux pas accéder di...
# 71                 2021  Je suis désolé, mais je ne peux pas accéder di...

# %%
df.to_parquet('data_sources_from_python\df_annee.parquet', engine='pyarrow')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\chric\AppData\Local\Temp\ipykernel_188\3199247240.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df.to_parquet('data_sources_from_python\df_annee.parquet', engine='pyarrow')

# %% [markdown]
# # trouver la série du livre et le numéro de série
# abandonné.
# Résultats mauvais et probleme de filtre azure open ai

# %%
df = pd.read_parquet('data_sources_from_python\df_book.parquet')

df = df.tail(16)
# # drop les id 2,10,27,35
# df = df[~df['id'].isin([2, 10, 27, 35])]
df.head(43)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\chric\AppData\Local\Temp\ipykernel_17708\309852426.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_parquet('data_sources_from_python\df_book.parquet')
#     id                                              Titre  \
# 55  57                                 Légendes et lattes
# 56  58  Roman secret 3 - Yumi et le peintre de cauchemars
# 57  59                           Les Variations Sebastian
# 58  60  Pouvoir, politique et esprits frappeurs enquiq...
# 59  61  Atomic Habits: An Easy & Proven Way to Build G...
# 60  62                    Leviathan Wakes - the expanse 1
# 61  63  Blackwater 1 - La crue: L'épique saga de la fa...
# 62  64                            Blackwater 2 - La digue
# 63  65                        Le livre des choses perdues
# 64  66  Histoires de moine et de robot T2 : Une prière...
# 65  67                      Voyageur 1 : L'Espace d'un an
# 66  68                             Voyageur 2 : Libration
# 67  69  Blackwater 3 – La Maison: L'épique saga de la ...
# 68  70                   Voyageur 3 : Archives de l'exode
# 69  71  Blackwater 4 – La Guerre: L'épique saga de la ...
# 70  72                 Voyageur 4 : La Galaxie vue du sol
#
#                  Auteurs  notes Date dernière ouverture  page  \
# 55        Travis Baldree      0              2024-07-18   397
# 56     Brandon Sanderson      0              2024-07-29   798
# 57  Emily St.John Mandel      0              2024-08-02   471
# 58         J. K. Rowling      0              2024-08-03    59
# 59           James Clear      0              2024-08-08   482
# 60     James S. A. Corey      0              2024-08-11   823
# 61      Michael McDowell      0              2024-08-18   248
# 62      Michael McDowell      0              2024-08-20   225
# 63         John Connolly      0              2024-09-09   480
# 64        Becky Chambers      0              2024-09-23   139
# 65        Becky Chambers      0              2024-09-29   789
# 66        Becky Chambers      0              2024-10-03   504
# 67      Michael McDowell      0              2024-10-08   213
# 68        Becky Chambers      0              2024-10-23   441
# 69      Michael McDowell      0              2024-10-27   257
# 70        Becky Chambers      0              2024-11-01   400
#
#                                 Série Langue  total_read_time  \
# 55                                N/A     fr          16919.0
# 56                                N/A     fr          26233.0
# 57                                N/A     fr          16163.0
# 58                                N/A    N/A            216.0
# 59                                N/A     en             94.0
# 60                     The Expanse #1     en          44807.0
# 61                      Blackwater #1     fr           9673.0
# 62                      Blackwater #2     it           9457.0
# 63                                N/A     fr          21326.0
# 64  Histoires de moine et de robot #2     fr           5787.0
# 65                   Les voyageurs #1     fr          26888.0
# 66                   Les voyageurs #2     fr          21135.0
# 67                      Blackwater #3     fr           8572.0
# 68                   Les voyageurs #3     fr          22254.0
# 69                      Blackwater #4     fr           8562.0
# 70                   Les voyageurs #4     fr           2951.0
#
#     total Nbr de pages lues id long     Auteurs courts format  \
# 55                      387   00057     Travis Baldree  ebook
# 56                      768   00058  Brandon Sanderson  ebook
# 57                      458   00059         Emily John  ebook
# 58                        4   00060            Rowling  ebook
# 59                        7   00061        James Clear  ebook
# 60                      815   00062        James Corey  ebook
# 61                      234   00063   Michael McDowell  ebook
# 62                      208   00064   Michael McDowell  ebook
# 63                      467   00065      John Connolly  ebook
# 64                      135   00066     Becky Chambers  ebook
# 65                      779   00067     Becky Chambers  ebook
# 66                      487   00068     Becky Chambers  ebook
# 67                      206   00069   Michael McDowell  ebook
# 68                      422   00070     Becky Chambers  ebook
# 69                      249   00071   Michael McDowell  ebook
# 70                       54   00072     Becky Chambers  ebook
#
#                 categorie                                             oeuvre  \
# 55        fiction/fantasy                Légendes et lattes - Travis Baldree
# 56        fiction/fantasy  Roman secret 3 - Yumi et le peintre de cauchem...
# 57    fiction/fantastique    Les Variations Sebastian - Emily St.John Mandel
# 58    fiction/fantastique  Pouvoir, politique et esprits frappeurs enquiq...
# 59  non-fiction/lifestyle  Atomic Habits: An Easy & Proven Way to Build G...
# 60             fiction/SF  Leviathan Wakes - the expanse 1 - James S. A. ...
# 61    fiction/fantastique  Blackwater 1 - La crue: L'épique saga de la fa...
# 62    fiction/fantastique         Blackwater 2 - La digue - Michael McDowell
# 63        fiction/fantasy        Le livre des choses perdues - John Connolly
# 64             fiction/SF  Histoires de moine et de robot T2 : Une prière...
# 65             fiction/SF     Voyageur 1 : L'Espace d'un an - Becky Chambers
# 66             fiction/SF            Voyageur 2 : Libration - Becky Chambers
# 67    fiction/fantastique  Blackwater 3 – La Maison: L'épique saga de la ...
# 68             fiction/SF  Voyageur 3 : Archives de l'exode - Becky Chambers
# 69    fiction/fantastique  Blackwater 4 – La Guerre: L'épique saga de la ...
# 70             fiction/SF  Voyageur 4 : La Galaxie vue du sol - Becky Cha...
#
#    First published date
# 55                 2022
# 56                 2023
# 57                 2014
# 58                 2023
# 59                 2018
# 60                 2011
# 61                 1983
# 62                 1983
# 63                 2006
# 64                 2022
# 65                 2014
# 66                 2022
# 67                 1983
# 68                 2020
# 69                 1983
# 70                 2021

# %%
df = pd.read_parquet('data_sources_from_python/df_book.parquet')
df = df.tail(16)

prompt_serie = """
en utilisant tes connaissances litteraires, identifie le nom de la série et le numéro auquel appartient l'oeuvre.
Les noms des oeuvres et des séries sont uniquement des noms de création artistique. 

Le format doit être : série - numéro.
exemple : 
La Galaxie vue du sol - Becky Chambers = Les voyageurs - 4
Harry Potter et la chambre des secrets - JK Rowling = Harry Potter - 2


si le livre ne fait pas partie d'une série, écris "1shot".
n'ajoute rien d'autre.
question: {oeuvre} 

série:"""
prompt = PromptTemplate.from_template(prompt_serie)

# langchain :
chain_find_serie_number = (
    {"oeuvre": RunnablePassthrough()}
    | prompt
    | llm_gpt4o
    | StrOutputParser()
)

	
# fonction pour créer une colonne catégorie
def find_serie_number(oeuvre):
    result = chain_find_serie_number.invoke(oeuvre)
    return result



df['Série'] = df.apply(
    lambda row: find_serie_number(row['oeuvre']) 
    if pd.isna(row['Série']) or row['Série'] == '' or row['Série'] == 'N/A' 
    else row['Série'],
    axis=1
)



df.head(10)


# # Exemple d'utilisation
# oeuvre = "La faune de l'espace	Van Vogt,Alfred E"
# resultat = find_serie_number(oeuvre)
# print(resultat)
# Out:
#     id                                              Titre  \
# 55  57                                 Légendes et lattes
# 56  58  Roman secret 3 - Yumi et le peintre de cauchemars
# 57  59                           Les Variations Sebastian
# 58  60  Pouvoir, politique et esprits frappeurs enquiq...
# 59  61  Atomic Habits: An Easy & Proven Way to Build G...
# 60  62                    Leviathan Wakes - the expanse 1
# 61  63  Blackwater 1 - La crue: L'épique saga de la fa...
# 62  64                            Blackwater 2 - La digue
# 63  65                        Le livre des choses perdues
# 64  66  Histoires de moine et de robot T2 : Une prière...
#
#                  Auteurs  notes Date dernière ouverture  page  \
# 55        Travis Baldree      0              2024-07-18   397
# 56     Brandon Sanderson      0              2024-07-29   798
# 57  Emily St.John Mandel      0              2024-08-02   471
# 58         J. K. Rowling      0              2024-08-03    59
# 59           James Clear      0              2024-08-08   482
# 60     James S. A. Corey      0              2024-08-11   823
# 61      Michael McDowell      0              2024-08-18   248
# 62      Michael McDowell      0              2024-08-20   225
# 63         John Connolly      0              2024-09-09   480
# 64        Becky Chambers      0              2024-09-23   139
#
#                                 Série Langue  total_read_time  \
# 55                              1shot     fr          16919.0
# 56                   Roman secret - 3     fr          26233.0
# 57                              1shot     fr          16163.0
# 58                   Harry Potter - 5    N/A            216.0
# 59                              1shot     en             94.0
# 60                     The Expanse #1     en          44807.0
# 61                      Blackwater #1     fr           9673.0
# 62                      Blackwater #2     it           9457.0
# 63                              1shot     fr          21326.0
# 64  Histoires de moine et de robot #2     fr           5787.0
#
#     total Nbr de pages lues id long     Auteurs courts format  \
# 55                      387   00057     Travis Baldree  ebook
# 56                      768   00058  Brandon Sanderson  ebook
# 57                      458   00059         Emily John  ebook
# 58                        4   00060            Rowling  ebook
# 59                        7   00061        James Clear  ebook
# 60                      815   00062        James Corey  ebook
# 61                      234   00063   Michael McDowell  ebook
# 62                      208   00064   Michael McDowell  ebook
# 63                      467   00065      John Connolly  ebook
# 64                      135   00066     Becky Chambers  ebook
#
#                 categorie                                             oeuvre  \
# 55        fiction/fantasy                Légendes et lattes - Travis Baldree
# 56        fiction/fantasy  Roman secret 3 - Yumi et le peintre de cauchem...
# 57    fiction/fantastique    Les Variations Sebastian - Emily St.John Mandel
# 58    fiction/fantastique  Pouvoir, politique et esprits frappeurs enquiq...
# 59  non-fiction/lifestyle  Atomic Habits: An Easy & Proven Way to Build G...
# 60             fiction/SF  Leviathan Wakes - the expanse 1 - James S. A. ...
# 61    fiction/fantastique  Blackwater 1 - La crue: L'épique saga de la fa...
# 62    fiction/fantastique         Blackwater 2 - La digue - Michael McDowell
# 63        fiction/fantasy        Le livre des choses perdues - John Connolly
# 64             fiction/SF  Histoires de moine et de robot T2 : Une prière...
#
#    First published date
# 55                 2022
# 56                 2023
# 57                 2014
# 58                 2023
# 59                 2018
# 60                 2011
# 61                 1983
# 62                 1983
# 63                 2006
# 64                 2022

# %%
df.tail(10)
# Out:
#     id                                              Titre           Auteurs  \
# 62  63  Blackwater 1 - La crue: L'épique saga de la fa...  Michael McDowell
# 63  64                            Blackwater 2 - La digue  Michael McDowell
# 64  65                        Le livre des choses perdues     John Connolly
# 65  66  Histoires de moine et de robot T2 : Une prière...    Becky Chambers
# 66  67                      Voyageur 1 : L'Espace d'un an    Becky Chambers
# 67  68                             Voyageur 2 : Libration    Becky Chambers
# 68  69  Blackwater 3 – La Maison: L'épique saga de la ...  Michael McDowell
# 69  70                   Voyageur 3 : Archives de l'exode    Becky Chambers
# 70  71  Blackwater 4 – La Guerre: L'épique saga de la ...  Michael McDowell
# 71  72                 Voyageur 4 : La Galaxie vue du sol    Becky Chambers
#
#     notes Date dernière ouverture  page  \
# 62      0              2024-08-18   248
# 63      0              2024-08-20   225
# 64      0              2024-09-09   480
# 65      0              2024-09-23   139
# 66      0              2024-09-29   789
# 67      0              2024-10-03   504
# 68      0              2024-10-08   213
# 69      0              2024-10-23   441
# 70      0              2024-10-27   257
# 71      0              2024-11-01   400
#
#                                                 Série Langue  total_read_time  \
# 62                                      Blackwater #1     fr           9673.0
# 63                                      Blackwater #2     it           9457.0
# 64  Le livre des choses perdues - John Connolly = ...     fr          21326.0
# 65                  Histoires de moine et de robot #2     fr           5787.0
# 66                                   Les voyageurs #1     fr          26888.0
# 67                                   Les voyageurs #2     fr          21135.0
# 68                                      Blackwater #3     fr           8572.0
# 69                                   Les voyageurs #3     fr          22254.0
# 70                                      Blackwater #4     fr           8562.0
# 71                                   Les voyageurs #4     fr           2951.0
#
#     total Nbr de pages lues id long    Auteurs courts format  \
# 62                      234   00063  Michael McDowell  ebook
# 63                      208   00064  Michael McDowell  ebook
# 64                      467   00065     John Connolly  ebook
# 65                      135   00066    Becky Chambers  ebook
# 66                      779   00067    Becky Chambers  ebook
# 67                      487   00068    Becky Chambers  ebook
# 68                      206   00069  Michael McDowell  ebook
# 69                      422   00070    Becky Chambers  ebook
# 70                      249   00071  Michael McDowell  ebook
# 71                       54   00072    Becky Chambers  ebook
#
#               categorie                                             oeuvre  \
# 62  fiction/fantastique  Blackwater 1 - La crue: L'épique saga de la fa...
# 63  fiction/fantastique         Blackwater 2 - La digue - Michael McDowell
# 64      fiction/fantasy        Le livre des choses perdues - John Connolly
# 65           fiction/SF  Histoires de moine et de robot T2 : Une prière...
# 66           fiction/SF     Voyageur 1 : L'Espace d'un an - Becky Chambers
# 67           fiction/SF            Voyageur 2 : Libration - Becky Chambers
# 68  fiction/fantastique  Blackwater 3 – La Maison: L'épique saga de la ...
# 69           fiction/SF  Voyageur 3 : Archives de l'exode - Becky Chambers
# 70  fiction/fantastique  Blackwater 4 – La Guerre: L'épique saga de la ...
# 71           fiction/SF  Voyageur 4 : La Galaxie vue du sol - Becky Cha...
#
#    First published date
# 62                 1983
# 63                 1983
# 64                 2006
# 65                 2022
# 66                 2014
# 67                 2022
# 68                 1983
# 69                 2020
# 70                 1983
# 71                 2021
